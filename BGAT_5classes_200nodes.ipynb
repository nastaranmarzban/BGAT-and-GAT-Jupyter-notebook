# %% [markdown]
# <a href="https://colab.research.google.com/github/nastaranmarzban/BGAT-and-GAT-Jupyter-notebook/blob/main/BGAT_5classes_200nodes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mount to gdrive to read data, adjacency matrix, p_link and labels.

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # Install pandas to read csv files from gdrive. Install torch and numpy which are packages that are needed durind coding.

# %%
# !pip install pandas
# !pip install kneed
import pandas as pd
import torch
import numpy as np
import time
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: kneed in /usr/local/lib/python3.10/dist-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.13.1)

# %% [markdown]
# # Load data which are processed in preprocessing data_5classes_200nodes.ipynb file.

# %%
path = F"/gdrive/MyDrive/5classes_200_non.sim/data.pt"
Data = torch.load(path)
Data
# Out:
# <ipython-input-3-118d2bf10472>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Data = torch.load(path)
# {'x': tensor([[ 0.1064,  0.0268,  0.0688,  ...,  0.1277,  0.0208,  0.0365],
#          [-1.1319,  0.0287, -1.2385,  ..., -0.1471,  1.4365, -0.7657],
#          [ 0.5656,  1.3512,  2.0302,  ...,  1.2031, -1.7998,  1.0181],
#          ...,
#          [-0.0979,  0.9709,  0.6932,  ..., -0.8765, -0.6086, -0.5979],
#          [ 1.9060, -0.2760,  1.1493,  ..., -1.1248,  0.7692,  0.6333],
#          [ 1.1451, -1.8192, -2.0841,  ...,  1.7384, -0.7770, -0.3205]]),
#  'edge_index': tensor([[  0,   0,   0,  ..., 199, 199, 199],
#          [  9,  12,  20,  ...,  90, 100, 174]]),
#  'y': tensor([2, 3, 4, 4, 4, 4, 0, 4, 4, 2, 3, 4, 1, 0, 2, 3, 1, 4, 3, 0, 0, 1, 1, 1,
#          1, 2, 4, 3, 1, 4, 1, 4, 0, 0, 2, 3, 0, 4, 1, 1, 3, 0, 0, 0, 1, 3, 4, 1,
#          3, 3, 0, 4, 2, 4, 4, 3, 3, 2, 2, 2, 3, 4, 4, 2, 4, 4, 3, 0, 4, 0, 3, 3,
#          0, 0, 1, 2, 4, 2, 0, 4, 4, 4, 2, 0, 0, 2, 0, 4, 0, 2, 3, 3, 2, 2, 3, 2,
#          2, 4, 4, 3, 3, 1, 1, 1, 0, 0, 2, 1, 2, 0, 0, 3, 3, 2, 1, 3, 3, 2, 1, 4,
#          0, 1, 3, 2, 3, 0, 4, 4, 0, 1, 2, 1, 3, 1, 4, 3, 2, 3, 4, 1, 4, 0, 1, 1,
#          2, 1, 2, 0, 3, 4, 2, 2, 2, 2, 3, 0, 4, 1, 2, 1, 2, 0, 0, 3, 0, 0, 0, 1,
#          1, 3, 1, 0, 1, 1, 3, 1, 4, 2, 2, 2, 1, 0, 3, 4, 1, 3, 0, 3, 0, 1, 4, 2,
#          0, 1, 2, 1, 2, 4, 3, 3]),
#  'train_mask': tensor([ True,  True,  True,  True,  True,  True, False,  True,  True,  True,
#           True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          False,  True,  True,  True,  True, False, False,  True,  True,  True,
#           True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#           True,  True,  True, False, False, False,  True,  True,  True,  True,
#           True, False,  True,  True,  True, False, False,  True,  True,  True,
#           True,  True,  True, False,  True, False,  True,  True, False,  True,
#           True,  True,  True, False,  True,  True, False,  True,  True,  True,
#           True,  True, False,  True,  True,  True,  True,  True,  True,  True,
#           True,  True, False,  True, False,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True, False,  True,  True,  True,  True, False,
#           True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True, False,  True,  True, False, False,  True, False,  True,  True,
#          False,  True, False, False, False,  True,  True,  True,  True, False,
#          False,  True, False, False,  True,  True,  True,  True, False,  True,
#          False, False,  True, False,  True,  True,  True,  True,  True,  True]),
#  'val_mask': tensor([False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False,  True,  True, False, False, False,
#          False, False, False,  True, False, False, False, False,  True, False,
#          False, False, False,  True, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False,  True, False,  True, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False,  True, False, False,  True,  True, False,  True, False, False,
#          False, False, False,  True, False, False, False, False, False, False,
#           True, False, False,  True, False, False, False, False, False, False,
#           True,  True, False,  True, False, False, False, False, False, False]),
#  'test_mask': tensor([False, False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False,  True, False, False, False, False,
#           True, False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False,  True, False, False, False, False, False,
#          False, False, False,  True,  True, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,  True,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#           True, False,  True, False,  True, False, False, False, False,  True,
#          False, False,  True, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False, False, False, False])}

# %% [markdown]
# # Gather some statistics about the graph.

# %%
print(f'Number of nodes: {Data["x"].size(0)}')
print(f'Number of features: {Data["x"].size(1)}')
print(f'Number of classes: {torch.numel(torch.unique(Data["y"],sorted=True))}')
print(f'Number of edges: {Data["edge_index"].size(1)}')
print(f'Average node degree: {Data["edge_index"].size(1) / Data["x"].size(0):.2f}')
print(f'Number of training nodes: {Data["train_mask"].sum()}')
print(f'Number of testing nodes: {Data["test_mask"].sum()}')
print(f'Training node label rate: {int(Data["train_mask"].sum()) /  Data["x"].size(0):.2f}')
# Out:
# Number of nodes: 200
# Number of features: 500
# Number of classes: 5
# Number of edges: 1790
# Average node degree: 8.95
# Number of training nodes: 160
# Number of testing nodes: 20
# Training node label rate: 0.80

# %% [markdown]
# # Read p_link from gdrive to use it as the attention.

# %%
path = F"/gdrive/MyDrive/5classes_200_non.sim/p_link.pt"
p_link = torch.load(path)
print(p_link.size())
print(p_link.dtype)
print(p_link.type())
# Out:
# torch.Size([200, 200])
# torch.float32
# torch.FloatTensor
# <ipython-input-5-0572c7641c16>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   p_link = torch.load(path)

# %% [markdown]
# # Install torch_geometic.

# %%
import os
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.5.1+cu121
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %% [markdown]
# # Developing my own model (making our own message passing layers), which name is BGAT.
#
# **BGATConv**
# $$ X^\prime _i = \sum_{j \in N(i)\cup i} \alpha_{ij}\Theta X_j$$
# In which $\alpha$s are computed via BDgraph (p_link) and $\Theta$ is learnable parameter

# %%
from torch_geometric.nn import MessagePassing
import torch_geometric.nn
import torch.nn.functional as F
from torch_geometric.utils import add_self_loops

# %% [markdown]
# # Creating message passing network.

# %%
class BGATConv(MessagePassing):
    def __init__(
        self,
        in_channels,
        out_channels,
        **kwargs,
    ):
        kwargs.setdefault('aggr', 'add')
        super().__init__(node_dim = 0, **kwargs)
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.lin = torch.nn.Linear(in_channels, out_channels)

    def forward(self, x, edge_index):
        edge_index, _ = add_self_loops(Data["edge_index"], num_nodes = Data["x"].size(0))
        x = self.lin(x)
        atten = p_link
        return self.propagate(edge_index, x=x, atten = atten)

    def message(self, x_j, atten, edge_index_i, edge_index_j):
        return atten[edge_index_i, edge_index_j].reshape(-1,1) * x_j

    def __repr__(self):
        return '{}({}, {})'.format(self.__class__.__name__, self.in_channels, self.out_channels)

# %% [markdown]
# # Make GNN layers with our own model, BGAT. We use three BGAT conv

# %%
class Myconv(torch.nn.Module):
    def __init__(self):
        super().__init__()
        torch.manual_seed(2)
        self.conv1 = BGATConv(in_channels = 500, out_channels = 15)
        self.conv2 =  BGATConv(15, 5)


    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = F.torch.tanh(h)
        h = self.conv2(h, edge_index)
        return h

model = Myconv()
print(model)
print(model.forward(Data["x"], Data["edge_index"]))
# Out:
# Myconv(
#   (conv1): BGATConv(500, 15)
#   (conv2): BGATConv(15, 5)
# )
# tensor([[ 2.1293e+00,  5.7953e-01,  7.9458e-01, -2.6776e+00,  3.8019e-01],
#         [-1.1192e+00, -2.1002e-01,  2.8241e+00, -8.8894e-01,  1.6564e+00],
#         [ 9.2704e-01,  1.6865e+00, -1.2808e+00, -2.2344e-01,  1.3138e+00],
#         [-4.0488e-01,  6.2004e-01, -2.5906e-02,  1.2410e+00,  3.5720e-01],
#         [ 1.2185e-01, -1.0387e+00,  1.0315e+00,  6.7436e-01,  1.9069e+00],
#         [-2.0061e-01,  2.6011e+00, -1.3580e+00,  2.0816e+00,  1.4664e+00],
#         [ 5.1985e-01, -3.3965e+00, -1.9293e+00, -1.9707e+00,  2.1323e+00],
#         [ 1.0053e+00,  3.8456e-01,  3.5055e+00, -5.6903e-01,  4.9274e-01],
#         [ 3.2808e-01,  6.6424e-01, -7.2094e-01,  9.3730e-01,  1.5317e+00],
#         [ 1.3183e+00, -1.3744e+00,  1.6096e-01, -2.2784e+00,  5.3167e-01],
#         [-6.6250e-01,  5.9416e-02,  1.0683e+00, -8.6587e-01,  1.2286e+00],
#         [ 1.9543e+00,  9.0314e-03,  3.2853e-01, -4.4265e-01,  8.4903e-01],
#         [-2.4369e+00, -2.0925e+00,  7.5896e+00, -1.7116e-01,  6.4379e+00],
#         [ 3.5701e-01, -4.3330e+00, -5.5898e-01, -6.3482e-01,  2.2737e+00],
#         [ 4.3186e-01, -8.0434e-02,  3.3104e-01, -1.4800e+00,  3.3054e-02],
#         [-9.3963e-01,  1.9751e+00,  2.0441e+00,  1.7698e+00,  1.8136e+00],
#         [-4.6274e+00, -1.6311e+00,  5.7971e+00, -1.6220e+00,  7.5421e+00],
#         [ 1.3895e+00, -1.3914e+00,  1.6974e+00, -4.8156e-01, -9.5137e-01],
#         [-5.0874e-01,  1.0433e+00,  1.3549e+00, -7.5418e-01,  1.2468e+00],
#         [ 8.8062e-01, -2.1318e+00,  1.1899e+00, -4.3563e+00,  2.2580e+00],
#         [ 6.6821e-01, -1.7617e+00,  1.5451e-01, -4.0009e+00,  1.9716e+00],
#         [-3.7950e+00, -4.8954e+00,  5.5668e+00,  8.2553e-03,  7.2716e+00],
#         [-6.3153e+00, -3.1666e+00,  6.6207e+00,  2.7115e+00,  9.7370e+00],
#         [-1.6454e+00, -2.4025e+00,  3.4959e+00,  3.8890e-01,  5.7762e+00],
#         [-2.5089e+00, -2.0877e+00,  3.6183e+00,  1.6024e+00,  3.9079e+00],
#         [ 1.5297e+00, -3.3661e+00, -1.0980e+00, -1.3388e+00,  1.6282e-01],
#         [ 2.4451e+00, -2.9765e+00,  1.7172e+00, -3.6753e+00,  1.2762e-01],
#         [-1.1926e+00,  1.5169e+00,  4.9975e+00, -1.0556e+00,  2.2164e+00],
#         [-3.1907e+00, -6.5765e+00,  3.6591e+00,  1.9600e+00,  5.4146e+00],
#         [ 2.0171e-01, -2.3949e-01,  3.2300e-01, -8.6936e-01,  2.3944e-02],
#         [-3.9827e+00, -8.8276e+00,  4.0834e+00,  2.0342e+00,  5.7668e+00],
#         [ 2.8819e-01,  2.1019e-01,  8.9504e-02, -8.4322e-01, -6.7302e-01],
#         [ 1.1901e-01, -3.4261e+00, -2.9567e-01, -2.8985e+00,  2.1559e+00],
#         [ 2.3062e+00, -3.9984e+00, -1.3730e+00, -3.0960e+00,  1.0659e+00],
#         [ 1.1193e+00, -2.0385e+00, -3.9177e-01, -8.5162e-01,  2.4877e-01],
#         [-1.0989e+00,  1.7852e-01,  2.8388e+00, -1.2364e+00,  1.6978e+00],
#         [-4.9057e-01, -3.0244e+00, -9.6405e-01, -5.1956e-01,  2.2337e+00],
#         [-8.2125e-01, -1.3211e-01,  1.4714e+00,  5.7340e-01,  1.3412e+00],
#         [-5.6140e+00, -4.7600e+00,  5.0159e+00,  4.8802e+00,  8.6554e+00],
#         [-4.5990e+00, -2.9666e+00,  5.0889e+00,  6.0275e-01,  7.0664e+00],
#         [-1.1746e+00, -2.0386e+00, -3.4352e-01, -7.5022e-01,  1.4255e+00],
#         [ 3.7954e-01, -1.4814e+00, -1.7646e+00,  4.8752e-02,  8.2876e-01],
#         [ 3.6419e-01, -4.5090e+00, -2.2504e+00, -1.0417e+00,  2.1813e+00],
#         [ 1.1736e+00, -9.3692e-01, -2.0851e-01, -1.4893e+00,  2.0459e+00],
#         [-5.6734e+00, -3.1251e+00,  4.9553e+00,  1.6631e+00,  9.2931e+00],
#         [-3.0960e-01, -6.5834e-01,  1.0287e+00, -1.2700e+00,  1.7386e+00],
#         [-4.3771e-01,  5.4224e-01,  5.1522e-01,  1.5242e-01,  2.0585e+00],
#         [-5.5932e+00, -5.1640e+00,  4.6406e+00,  7.0825e-01,  5.8849e+00],
#         [ 6.9793e-01, -1.0184e+00,  7.0172e-01, -6.7834e-01, -1.5559e+00],
#         [-2.8929e+00,  1.6326e+00,  7.4365e+00, -2.7250e+00,  3.2728e+00],
#         [ 1.4395e+00, -4.9945e+00, -1.1239e+00, -2.6588e+00,  8.0805e-01],
#         [ 1.0796e+00,  4.6699e-01,  6.4881e-01, -2.7350e+00,  7.6564e-01],
#         [ 1.3382e-01, -2.2903e+00, -6.0023e-02, -8.6568e-01,  2.6541e+00],
#         [-6.5319e-01,  7.1525e-01,  1.6477e+00,  5.5327e-01,  3.1220e+00],
#         [-9.2860e-01, -2.2646e-01,  2.6302e-01,  4.0383e-01, -3.2471e-01],
#         [-1.2217e-01,  4.0335e-01,  1.1284e+00, -2.6590e+00,  6.9502e-01],
#         [ 7.3185e-01,  7.8166e-01,  2.2975e+00, -5.6240e-01,  5.8924e-01],
#         [ 7.0449e-01, -1.2937e+00, -3.7635e-01, -9.4852e-01,  6.7373e-01],
#         [ 4.9951e-01, -3.0470e+00, -1.3624e+00, -1.4569e+00,  4.9370e-01],
#         [-2.3179e-01, -1.3396e+00,  3.9698e-01, -3.7799e-01,  1.0664e+00],
#         [-1.1109e+00,  5.5921e-01,  3.2811e+00, -1.4888e+00,  1.5335e+00],
#         [ 9.7176e-01, -1.7026e+00,  1.1590e+00, -2.7097e+00,  1.8025e+00],
#         [ 1.3732e-01, -4.3252e-03,  1.6267e-01,  5.0630e-02,  2.9907e-02],
#         [ 8.5762e-01, -2.7103e+00, -1.4599e+00, -1.7955e+00,  1.2330e+00],
#         [-1.0264e+00, -2.9830e-01,  1.8773e+00,  8.1166e-01,  2.1078e+00],
#         [ 5.8003e-01,  1.7553e+00, -1.3317e+00,  1.3893e+00,  4.8186e-01],
#         [-7.1686e-01, -1.0546e+00,  1.6532e+00, -2.0677e+00,  1.2025e+00],
#         [-6.3668e-02, -3.5899e+00, -6.2314e-01, -1.5645e+00,  2.0636e+00],
#         [ 3.9929e+00, -4.4753e-01,  6.3737e-01, -3.3600e+00,  6.3776e-01],
#         [ 2.0610e+00, -3.8994e+00, -1.8171e+00, -3.0485e+00,  3.0805e+00],
#         [-1.1051e+00, -2.7867e-01,  2.7975e+00, -2.3307e+00,  1.0164e+00],
#         [-1.3256e+00,  1.3474e+00,  2.6581e+00, -4.1039e-01,  1.3350e+00],
#         [ 6.0314e-01, -2.7003e+00, -2.1195e+00, -1.3328e+00,  1.5316e+00],
#         [ 7.4176e-01, -2.6159e+00, -1.4472e+00, -1.1527e+00,  1.0801e+00],
#         [-5.1989e+00, -6.9077e+00,  4.6338e+00,  2.2062e+00,  5.8949e+00],
#         [ 1.8411e-01, -1.0062e+00,  2.4424e-01, -2.2028e+00,  7.5621e-01],
#         [ 1.8432e+00, -1.4693e+00,  2.6602e+00, -1.1499e+00, -4.4370e-03],
#         [ 1.6620e+00, -2.1760e+00,  9.2202e-02, -2.0035e+00,  7.1008e-02],
#         [ 5.8246e-01, -2.3679e+00, -1.1556e+00, -1.0621e+00,  8.1107e-01],
#         [ 2.7523e-01,  5.5105e-01, -1.0740e+00, -1.0233e-01,  1.9537e+00],
#         [ 9.9861e-01,  1.0535e+00,  2.9448e-01, -2.7961e+00,  8.7211e-01],
#         [ 1.9346e+00,  1.1351e+00,  2.3008e+00, -1.1479e+00,  8.1119e-01],
#         [ 4.5629e-01, -1.5763e+00, -8.0755e-01, -1.3415e+00, -1.1319e-01],
#         [ 8.4055e-01, -1.4681e+00, -1.1163e+00, -1.3318e+00,  1.6918e+00],
#         [ 1.9426e+00, -5.4697e+00, -4.6768e-01, -3.9801e+00,  9.6862e-01],
#         [ 1.2955e+00, -9.8266e-01, -8.3839e-01, -1.4116e+00,  1.9185e-01],
#         [ 1.9223e+00, -3.4332e+00, -1.9937e+00, -2.0643e+00,  1.0313e+00],
#         [-8.6318e-01,  2.3648e+00,  2.0317e+00,  1.3066e+00,  2.5627e+00],
#         [ 8.3387e-01, -2.6778e+00, -1.4218e+00, -1.6734e+00,  1.6717e+00],
#         [ 1.0966e+00, -4.8457e+00, -1.6674e-01, -3.0340e+00,  3.1627e+00],
#         [ 2.6215e-01, -4.1779e-01,  1.5536e+00, -8.5921e-01, -4.6756e-03],
#         [-6.2279e-02,  1.5299e+00,  3.7891e-01,  2.2485e-01, -8.1192e-01],
#         [ 7.3345e-01, -5.1919e+00, -1.9002e+00, -1.4301e+00,  2.4226e+00],
#         [ 8.1827e-01, -2.9281e+00, -2.0475e-01, -2.2872e+00,  9.2690e-04],
#         [ 1.8578e-01,  9.2255e-01,  1.1857e+00, -2.2220e-01, -8.1950e-02],
#         [ 4.1767e-01, -1.7828e+00, -2.8879e-01, -1.0749e+00,  7.2173e-01],
#         [ 1.0226e+00, -1.7801e+00, -1.2117e+00, -8.7814e-01,  4.6575e-01],
#         [-4.1222e-01,  7.3961e-01,  1.7337e-01,  2.4516e+00,  5.6281e-01],
#         [-8.4538e-01,  1.8511e+00, -1.4845e+00,  2.0359e+00,  2.6218e+00],
#         [ 2.8711e-01, -5.5281e-01,  4.4103e-01, -5.8034e-01, -4.8163e-01],
#         [-1.8412e+00, -1.0247e-01,  3.2864e+00, -9.8314e-02,  2.4318e+00],
#         [-3.1808e+00, -3.0375e+00,  5.9080e+00, -8.3605e-01,  7.9130e+00],
#         [-4.3739e+00, -5.2823e+00,  6.3806e+00,  2.1894e+00,  6.5390e+00],
#         [-4.7654e+00, -5.4336e+00,  5.9491e+00,  3.2859e+00,  7.9081e+00],
#         [ 1.1859e+00, -5.0680e+00, -1.4638e+00, -2.1528e+00,  1.1270e+00],
#         [ 1.1537e+00, -3.7455e+00, -1.2955e-01, -2.7891e+00,  1.4427e+00],
#         [ 2.8210e-01, -1.9720e+00, -1.1556e+00, -1.2711e+00, -2.6878e-01],
#         [-3.0774e+00, -3.1182e+00,  6.6460e+00,  8.8219e-01,  8.3074e+00],
#         [ 1.0009e+00, -1.5609e+00, -4.1029e-02, -8.7720e-01,  5.9454e-02],
#         [ 1.2639e+00, -4.3304e+00, -4.9271e-01, -3.0049e+00,  2.2508e+00],
#         [-5.3723e-01, -2.3456e+00, -4.2931e-01, -9.0828e-01,  2.8012e+00],
#         [-1.3159e+00, -2.6956e+00, -3.4841e-01, -9.7977e-01,  5.7790e-01],
#         [-5.5755e-01,  5.0334e-01,  8.2901e-01, -6.0852e-01,  9.1906e-01],
#         [-6.4668e-01, -7.0333e-01, -5.9210e-01, -2.6327e-03,  8.5665e-01],
#         [-6.2595e+00, -5.7259e+00,  7.8933e+00,  2.0511e+00,  1.0031e+01],
#         [ 7.2926e-01, -1.2665e+00,  4.8051e-02, -1.2545e+00, -1.0757e+00],
#         [-2.2223e+00, -5.9770e+00, -8.4862e-01, -2.2741e+00,  2.0623e+00],
#         [ 7.4225e-01, -2.1795e+00, -1.4026e+00, -1.2860e+00,  5.1426e-01],
#         [-4.3719e+00, -3.5694e+00,  6.3312e+00,  1.8922e+00,  9.8876e+00],
#         [-9.2191e-02, -1.1321e+00, -9.4111e-01, -1.1060e+00,  3.5277e+00],
#         [ 5.0823e-01, -1.7771e+00, -4.7616e-01, -6.2678e-01,  1.7857e+00],
#         [-5.5432e+00, -7.2544e+00,  7.2566e+00,  3.5110e+00,  1.1259e+01],
#         [-9.2716e-01,  2.8071e-01, -5.9186e-02,  1.5883e+00, -4.2498e-01],
#         [ 4.7740e-01, -3.2670e+00, -1.3542e+00, -7.6799e-01,  1.0809e+00],
#         [-1.0703e+00, -2.4543e-01, -2.3393e-01,  2.1178e+00, -9.9109e-02],
#         [ 1.0902e+00, -1.4437e+00, -1.1451e+00, -9.4302e-01,  2.5024e+00],
#         [-5.9833e-01, -7.2022e-01,  1.1989e-01,  1.5702e-01,  1.6003e+00],
#         [ 1.2257e+00,  2.2190e+00,  2.8758e-02, -1.2899e+00,  1.0157e+00],
#         [ 1.7294e+00, -4.2566e+00,  1.3127e-01, -4.3784e+00,  3.4853e+00],
#         [-2.6681e+00, -1.9105e+00,  5.5068e+00, -1.9171e+00,  2.2206e+00],
#         [ 2.2132e+00, -3.6662e+00, -1.7019e-01, -3.7543e+00,  2.4984e+00],
#         [-3.8094e+00, -3.2316e+00,  5.7081e+00, -4.9014e-01,  7.4527e+00],
#         [-1.8845e+00, -3.1051e+00, -1.7587e+00, -4.9936e-01,  2.5055e+00],
#         [-2.6844e+00, -5.5069e+00,  4.1295e+00,  9.7306e-01,  4.2215e+00],
#         [ 9.6770e-02,  4.6629e-01,  5.0400e-01,  1.3883e+00,  1.0345e+00],
#         [-1.2505e+00, -1.3417e+00, -1.6504e-02,  1.0626e+00,  2.0366e+00],
#         [ 1.0490e+00, -1.1120e+00, -9.7589e-02, -1.3389e+00,  5.9009e-01],
#         [ 1.2246e+00,  8.7283e-01,  1.8748e+00, -1.2535e+00,  1.5609e+00],
#         [-1.5377e-01, -1.5701e-01,  2.6375e-01, -1.3398e+00,  1.8842e+00],
#         [-5.4659e+00, -6.2748e+00,  5.5453e+00,  1.8945e+00,  8.1615e+00],
#         [ 7.2681e-01,  1.0054e+00,  9.6500e-01, -7.4004e-01,  2.6317e-01],
#         [ 1.5636e+00, -3.5949e+00, -2.2713e+00, -1.8348e+00,  2.0172e+00],
#         [-3.6836e+00, -7.8034e+00,  5.5224e+00,  1.9061e+00,  8.0728e+00],
#         [-4.9495e+00, -6.0823e+00,  2.6011e+00,  2.6377e+00,  7.6070e+00],
#         [ 1.5930e+00, -4.1956e+00, -1.3794e+00, -2.3660e+00,  1.5792e+00],
#         [-4.4391e+00, -6.0045e+00,  5.2763e+00,  8.3817e-01,  8.4527e+00],
#         [ 1.0349e+00, -4.7933e+00, -1.1217e+00, -2.6886e+00,  1.0310e+00],
#         [ 8.8384e-01, -2.1632e+00, -1.0407e+00, -1.3551e+00,  1.6338e+00],
#         [-5.6409e-01,  1.0340e+00,  7.4120e-01, -2.1972e+00,  2.1891e+00],
#         [-3.4762e-01,  4.0929e-01,  6.3078e-01,  3.6261e-01,  1.1699e+00],
#         [ 1.0890e-01, -3.2278e+00, -1.7314e+00, -1.5195e+00,  6.5503e-01],
#         [-3.9135e-01, -1.7280e+00, -7.9106e-01, -3.8486e-01,  5.9562e-01],
#         [ 1.3476e+00, -3.5946e+00, -1.8911e+00, -1.2213e+00,  1.0561e+00],
#         [-2.8137e-02, -9.7249e-01,  7.6862e-02, -4.2246e-01,  2.9652e-01],
#         [-5.5677e-01,  2.2435e+00,  4.0956e+00, -9.5163e-01,  6.2066e-01],
#         [ 1.1812e+00, -3.8691e+00, -1.8658e+00, -1.4855e+00,  2.3446e+00],
#         [-2.1631e+00,  2.1906e-01, -6.9446e-01,  1.7307e+00,  3.2410e+00],
#         [-5.1014e+00, -8.1149e+00,  5.5926e+00,  4.8272e+00,  8.9969e+00],
#         [ 2.0078e+00, -2.8403e+00,  2.0451e+00, -5.8531e+00,  2.6953e+00],
#         [-3.7313e+00, -3.9686e+00,  6.9969e+00,  7.1837e-01,  8.4354e+00],
#         [ 1.7039e+00,  1.1900e-01,  9.2516e-01, -1.7880e+00,  6.3374e-02],
#         [ 8.4318e-01, -3.8895e+00, -1.2381e+00, -1.0289e+00,  8.9005e-01],
#         [ 1.0563e+00, -3.1203e+00, -1.4682e+00, -1.8439e+00,  1.5568e+00],
#         [-2.6490e-01,  1.0964e+00,  1.2414e+00, -1.6564e+00,  1.5936e+00],
#         [ 4.5518e-01, -1.7037e+00, -1.0508e+00, -1.7443e+00,  1.5164e+00],
#         [ 8.2345e-01, -5.2796e+00, -8.5257e-01, -2.8038e+00,  3.6542e+00],
#         [ 9.5556e-01, -4.1927e+00, -2.3069e+00, -1.6234e+00,  2.7941e+00],
#         [-1.7915e+00, -4.4459e+00,  4.3068e+00, -8.1456e-01,  3.5289e+00],
#         [-3.5790e+00, -2.1668e+00,  7.1144e+00, -1.0932e+00,  6.8587e+00],
#         [-1.0368e+00, -2.8055e+00, -8.3712e-01, -1.0364e+00,  1.3536e+00],
#         [-5.5160e+00, -1.8566e+00,  4.9920e+00,  9.1871e-01,  9.7138e+00],
#         [ 8.8649e-01, -2.5030e+00, -1.2040e+00, -8.4303e-01,  1.8944e+00],
#         [-5.4152e+00, -5.7533e+00,  4.7431e+00,  4.6648e+00,  7.8449e+00],
#         [-4.3072e+00, -5.0000e+00,  4.1392e+00,  2.3378e+00,  5.5576e+00],
#         [ 2.6680e-01,  7.9558e-01,  1.8213e+00, -2.8875e+00,  6.2620e-01],
#         [-3.5577e+00, -3.2542e+00,  4.3410e+00, -1.0098e-02,  5.6747e+00],
#         [ 8.5021e-01, -7.9515e-02,  8.9217e-01, -5.1174e-01, -7.7308e-01],
#         [ 7.3025e-01, -1.9625e+00, -1.0964e+00, -7.5701e-01,  1.4891e-01],
#         [ 1.2314e+00, -1.8880e+00, -1.8010e+00, -2.1275e+00,  9.8348e-01],
#         [ 7.8701e-01, -3.2052e+00, -1.8384e+00, -1.2952e+00,  1.2202e+00],
#         [-6.7490e+00, -4.9534e+00,  7.3899e+00,  8.3617e-01,  8.9140e+00],
#         [-3.2203e-01, -2.2153e+00,  7.0255e-01, -1.0215e+00,  2.4090e+00],
#         [-1.4930e+00,  3.3315e-01,  3.7523e+00, -5.9465e-01,  2.5894e+00],
#         [ 1.5942e+00, -1.1893e+00,  8.2343e-01, -1.2268e+00,  5.8794e-01],
#         [-4.4663e+00, -8.5284e+00,  7.3697e+00,  3.3918e+00,  8.4499e+00],
#         [-3.0726e-01, -3.3108e-01,  1.6497e+00, -1.7295e+00,  5.5790e-01],
#         [ 7.7631e-01, -2.9814e+00, -8.6847e-01, -7.4028e-01,  1.8806e+00],
#         [-2.3645e-01, -1.0091e+00,  5.2527e-01, -7.6536e-01,  9.4428e-01],
#         [ 2.0988e-01, -1.3090e+00, -5.6343e-01, -1.0653e+00,  1.5948e+00],
#         [-4.4012e+00, -4.9392e+00,  5.7935e+00,  7.4636e-01,  5.7765e+00],
#         [-1.6780e-01,  2.5543e+00,  6.9412e-01, -9.6019e-01,  8.2237e-01],
#         [ 1.5699e+00, -1.5963e+00,  7.0381e-01, -7.0991e-01,  1.1846e+00],
#         [ 7.5322e-01, -3.5485e+00, -1.5929e+00, -1.4866e+00,  1.7470e+00],
#         [-3.3451e+00, -5.1196e+00,  5.7619e+00,  1.1766e-02,  5.5296e+00],
#         [-6.2312e-01, -3.9078e-01,  5.3356e-01,  3.6449e-01,  2.0339e+00],
#         [-5.8742e+00, -1.1194e+00,  6.9732e+00,  8.0891e-01,  9.5527e+00],
#         [ 2.1124e+00, -2.8673e+00, -4.4114e-01, -9.5945e-01,  6.0770e-02],
#         [-1.6748e+00,  1.1314e-01,  1.0788e+00,  1.5768e-02,  2.0394e+00],
#         [-2.1283e-01,  3.7140e-01,  1.8463e+00,  5.3119e-01,  1.4358e+00],
#         [-1.8899e+00,  1.3884e-02,  3.3072e+00, -5.1560e+00,  1.5193e+00]],
#        grad_fn=<ScatterAddBackward0>)

# %% [markdown]
# # We take a look at the node embeddings produced by our GNN (before training).

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

def visualize(h):
    z = TSNE(n_components = 2, random_state = 0).fit_transform(h.detach().numpy())
    plt.figure(figsize = (6,4),  dpi = 120)
    sns.scatterplot(x = z[:, 0], y = z[:, 1], hue = Data["y"], palette=sns.color_palette("bright",7)).set(title = "Second scenario data T-SNE projection before training (BGAT)")

# %% [markdown]
# Here, we pass in the initial node features x and the graph connectivity information edge_index to the model, and visualize its 2-dimensional embedding

# %%
model = Myconv()
h = model(Data["x"], Data["edge_index"])

print(f'Embedding shape: {list(h.shape)}')
visualize(h)
# Out:
# Embedding shape: [200, 5]
# <ipython-input-10-8bde51ee94e9>:8: UserWarning: The palette list has more values (7) than needed (5), which may not be intended.
#   sns.scatterplot(x = z[:, 0], y = z[:, 1], hue = Data["y"], palette=sns.color_palette("bright",7)).set(title = "Second scenario data T-SNE projection before training (BGAT)")

# %% [markdown]
# # Start training the model.

# %%
model = Myconv()
criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
optimizer = torch.optim.Adam(model.parameters(),  lr = 0.005)  # Define optimizer, an object for updating parameters
#loss = loss + weight decay parameter * L2 norm of the weights, 1) To prevent overfitting 2) To keep the weights small and avoid exploding gradient

def train(Data):
    model.train()
    optimizer.zero_grad()  # Clear gradients.
    out = model(Data["x"], Data["edge_index"])
    train_loss = criterion(out[Data["train_mask"]], Data["y"][Data["train_mask"]])  # Compute the loss solely based on the training nodes.
    train_loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    return train_loss


def val(Data):
      model.eval()
      with torch.no_grad():
        out = model(Data["x"], Data["edge_index"])
        val_loss = criterion(out[Data["val_mask"]], Data["y"][Data["val_mask"]])
        return val_loss

# %%
train_loss_ = []
val_loss_ = []

# Start timer before training begins
start_time = time.time()

for epoch in range(1, 59):
    # Start timer for the epoch
    epoch_start_time = time.time()

    # Initialize lists to track forward and backward pass times
    forward_times = []
    backward_times = []

    epoch_train_loss = []
    epoch_val_loss = []

    # Training
    model.train()
    optimizer.zero_grad()  # Clear gradients

    # Measure forward pass time
    forward_start = time.time()
    out = model(Data["x"], Data["edge_index"])  # Forward pass
    forward_end = time.time()

    # Compute loss
    train_loss = criterion(out[Data["train_mask"]], Data["y"][Data["train_mask"]])

    # Measure backward pass time
    backward_start = time.time()
    train_loss.backward()  # Backward pass
    optimizer.step()  # Update parameters
    backward_end = time.time()

    # Record forward and backward pass times
    forward_times.append(forward_end - forward_start)
    backward_times.append(backward_end - backward_start)

    # Record training loss
    epoch_train_loss.append(train_loss.item())

    # Validation
    model.eval()
    with torch.no_grad():
        out = model(Data["x"], Data["edge_index"])
        val_loss = criterion(out[Data["val_mask"]], Data["y"][Data["val_mask"]])
        epoch_val_loss.append(val_loss.item())

    # Append epoch-wise average loss
    train_loss_.append(sum(epoch_train_loss) / len(epoch_train_loss))
    val_loss_.append(sum(epoch_val_loss) / len(epoch_val_loss))

    # End timer for the epoch
    epoch_end_time = time.time()
    epoch_time = epoch_end_time - epoch_start_time

    # Log losses and times
    print(epoch,
      f'Train Loss: {train_loss_[-1]:.3f} | Val Loss: {val_loss_[-1]:.3f} | '
      f'Forward Time: {np.mean(forward_times):.4f}s | Backward Time: {np.mean(backward_times):.4f}s | '
      f'Epoch Time: {epoch_time:.2f}s')

# End timer after training completes
end_time = time.time()
total_training_time = end_time - start_time

print(f"Total training time: {total_training_time/59:.2f} seconds")
# Out:
# 1 Train Loss: 4.215 | Val Loss: 2.767 | Forward Time: 0.0021s | Backward Time: 0.0029s | Epoch Time: 0.01s
# 2 Train Loss: 1.683 | Val Loss: 2.007 | Forward Time: 0.0030s | Backward Time: 0.0017s | Epoch Time: 0.01s
# 3 Train Loss: 1.461 | Val Loss: 0.985 | Forward Time: 0.0026s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 4 Train Loss: 0.736 | Val Loss: 0.935 | Forward Time: 0.0027s | Backward Time: 0.0027s | Epoch Time: 0.01s
# 5 Train Loss: 0.680 | Val Loss: 0.934 | Forward Time: 0.0029s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 6 Train Loss: 0.655 | Val Loss: 0.757 | Forward Time: 0.0023s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 7 Train Loss: 0.550 | Val Loss: 0.523 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 8 Train Loss: 0.436 | Val Loss: 0.359 | Forward Time: 0.0023s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 9 Train Loss: 0.364 | Val Loss: 0.300 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 10 Train Loss: 0.338 | Val Loss: 0.300 | Forward Time: 0.0013s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 11 Train Loss: 0.339 | Val Loss: 0.304 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 12 Train Loss: 0.335 | Val Loss: 0.283 | Forward Time: 0.0013s | Backward Time: 0.0014s | Epoch Time: 0.01s
# 13 Train Loss: 0.311 | Val Loss: 0.250 | Forward Time: 0.0060s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 14 Train Loss: 0.275 | Val Loss: 0.219 | Forward Time: 0.0012s | Backward Time: 0.0015s | Epoch Time: 0.00s
# 15 Train Loss: 0.244 | Val Loss: 0.199 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 16 Train Loss: 0.224 | Val Loss: 0.186 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 17 Train Loss: 0.211 | Val Loss: 0.177 | Forward Time: 0.0023s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 18 Train Loss: 0.203 | Val Loss: 0.169 | Forward Time: 0.0012s | Backward Time: 0.0015s | Epoch Time: 0.00s
# 19 Train Loss: 0.194 | Val Loss: 0.162 | Forward Time: 0.0022s | Backward Time: 0.0044s | Epoch Time: 0.01s
# 20 Train Loss: 0.182 | Val Loss: 0.155 | Forward Time: 0.0040s | Backward Time: 0.0017s | Epoch Time: 0.01s
# 21 Train Loss: 0.167 | Val Loss: 0.150 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 22 Train Loss: 0.154 | Val Loss: 0.148 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 23 Train Loss: 0.147 | Val Loss: 0.149 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 24 Train Loss: 0.142 | Val Loss: 0.151 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 25 Train Loss: 0.140 | Val Loss: 0.151 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 26 Train Loss: 0.138 | Val Loss: 0.149 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 27 Train Loss: 0.134 | Val Loss: 0.143 | Forward Time: 0.0022s | Backward Time: 0.0017s | Epoch Time: 0.01s
# 28 Train Loss: 0.129 | Val Loss: 0.136 | Forward Time: 0.0012s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 29 Train Loss: 0.124 | Val Loss: 0.128 | Forward Time: 0.0014s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 30 Train Loss: 0.119 | Val Loss: 0.121 | Forward Time: 0.0012s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 31 Train Loss: 0.115 | Val Loss: 0.116 | Forward Time: 0.0023s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 32 Train Loss: 0.112 | Val Loss: 0.111 | Forward Time: 0.0023s | Backward Time: 0.0020s | Epoch Time: 0.01s
# 33 Train Loss: 0.109 | Val Loss: 0.108 | Forward Time: 0.0026s | Backward Time: 0.0036s | Epoch Time: 0.01s
# 34 Train Loss: 0.107 | Val Loss: 0.104 | Forward Time: 0.0020s | Backward Time: 0.0021s | Epoch Time: 0.01s
# 35 Train Loss: 0.104 | Val Loss: 0.101 | Forward Time: 0.0016s | Backward Time: 0.0019s | Epoch Time: 0.01s
# 36 Train Loss: 0.102 | Val Loss: 0.099 | Forward Time: 0.0029s | Backward Time: 0.0021s | Epoch Time: 0.01s
# 37 Train Loss: 0.099 | Val Loss: 0.096 | Forward Time: 0.0016s | Backward Time: 0.0020s | Epoch Time: 0.01s
# 38 Train Loss: 0.096 | Val Loss: 0.093 | Forward Time: 0.0015s | Backward Time: 0.0020s | Epoch Time: 0.01s
# 39 Train Loss: 0.093 | Val Loss: 0.091 | Forward Time: 0.0021s | Backward Time: 0.0021s | Epoch Time: 0.01s
# 40 Train Loss: 0.090 | Val Loss: 0.089 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.00s
# 41 Train Loss: 0.088 | Val Loss: 0.087 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 42 Train Loss: 0.085 | Val Loss: 0.085 | Forward Time: 0.0022s | Backward Time: 0.0014s | Epoch Time: 0.01s
# 43 Train Loss: 0.083 | Val Loss: 0.084 | Forward Time: 0.0012s | Backward Time: 0.0014s | Epoch Time: 0.01s
# 44 Train Loss: 0.080 | Val Loss: 0.082 | Forward Time: 0.0013s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 45 Train Loss: 0.078 | Val Loss: 0.080 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 46 Train Loss: 0.076 | Val Loss: 0.077 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 47 Train Loss: 0.074 | Val Loss: 0.074 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 48 Train Loss: 0.072 | Val Loss: 0.071 | Forward Time: 0.0012s | Backward Time: 0.0014s | Epoch Time: 0.01s
# 49 Train Loss: 0.070 | Val Loss: 0.068 | Forward Time: 0.0023s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 50 Train Loss: 0.068 | Val Loss: 0.065 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 51 Train Loss: 0.066 | Val Loss: 0.061 | Forward Time: 0.0014s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 52 Train Loss: 0.064 | Val Loss: 0.058 | Forward Time: 0.0026s | Backward Time: 0.0016s | Epoch Time: 0.01s
# 53 Train Loss: 0.062 | Val Loss: 0.055 | Forward Time: 0.0023s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 54 Train Loss: 0.060 | Val Loss: 0.052 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 55 Train Loss: 0.058 | Val Loss: 0.050 | Forward Time: 0.0022s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 56 Train Loss: 0.056 | Val Loss: 0.047 | Forward Time: 0.0013s | Backward Time: 0.0015s | Epoch Time: 0.01s
# 57 Train Loss: 0.054 | Val Loss: 0.045 | Forward Time: 0.0015s | Backward Time: 0.0026s | Epoch Time: 0.01s
# 58 Train Loss: 0.053 | Val Loss: 0.044 | Forward Time: 0.0096s | Backward Time: 0.0026s | Epoch Time: 0.02s
# Total training time: 0.01 seconds

# %% [markdown]
# # Visualize train loss and val loss.

# %%
plt.plot(train_loss_, "m", linewidth = 3)
plt.plot(val_loss_, "k", linewidth = 3)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Train','Val'])
plt.title('Train vs Val Loss for the second scenario (BGAT)')
plt.grid()
plt.show()

# %%
from kneed import KneeLocator

# Plot training and validation loss
plt.plot(train_loss_, "m", linewidth=3, label="Train Loss")
plt.plot(val_loss_, "k", linewidth=3, label="Validation Loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Val Loss for the First Scenario (BGAT)')
plt.legend()
plt.grid()

# Identify the elbow point
epochs = list(range(1, len(train_loss_) + 1))
knee_locator = KneeLocator(epochs, val_loss_, curve='convex', direction='decreasing')
elbow_epoch = knee_locator.knee
print(f"Elbow Point (Optimal Epoch): {elbow_epoch}")

# Highlight the elbow point on the plot
plt.axvline(x=elbow_epoch, color='r', linestyle='--', label=f'Elbow Point: {elbow_epoch}')
plt.legend()
plt.show()
# Out:
# Elbow Point (Optimal Epoch): 9

# %% [markdown]
# # Compute the accuracy of the model.

# %%
def test(Data):
      model.eval()
      with torch.no_grad():
        out = model(Data["x"], Data["edge_index"])
        pred = out.argmax(dim=1)
        test_correct = pred[Data["test_mask"]] == Data["y"][Data["test_mask"]]  # Check against ground-truth labels.
        test_acc = int(test_correct.sum()) / int(Data["test_mask"].sum())  # Derive ratio of correct predictions.
        return test_acc

# %%
test_acc = test(Data)
print(f'Test Accuracy: {100*test_acc:.2f}')
# Out:
# Test Accuracy: 95.00

# %% [markdown]
# # We take a look at the node embeddings produced by our GNN (after training).

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

def visualize(h):
    z = TSNE(n_components = 2, random_state = 0).fit_transform(h.detach().numpy())
    plt.figure(figsize = (6,4),  dpi = 120)
    sns.scatterplot(x = z[:, 0], y = z[:, 1], hue = Data["y"], palette=sns.color_palette("bright",5)).set(title = "Second scenario data T-SNE projection after training (BGAT)")

# %%
model.eval()
out = model(Data["x"], Data["edge_index"])
visualize(out)

# %% [markdown]
# # Confusion matrix.

# %%
pred_t = out.argmax(dim=1)
pred_t
# Out:
# tensor([2, 3, 4, 4, 4, 4, 0, 4, 4, 2, 3, 4, 1, 0, 2, 3, 1, 4, 3, 0, 0, 1, 1, 1,
#         1, 2, 4, 3, 1, 4, 1, 4, 0, 0, 2, 3, 0, 4, 1, 1, 3, 0, 0, 0, 1, 3, 4, 1,
#         3, 3, 0, 4, 2, 4, 4, 3, 3, 2, 2, 2, 3, 4, 4, 2, 4, 4, 3, 0, 4, 0, 3, 3,
#         0, 0, 1, 2, 4, 2, 0, 4, 4, 4, 2, 0, 0, 2, 0, 4, 0, 2, 3, 3, 2, 2, 3, 2,
#         2, 4, 4, 3, 3, 1, 1, 1, 0, 0, 2, 1, 2, 0, 0, 3, 3, 2, 1, 4, 3, 2, 1, 4,
#         0, 1, 3, 2, 3, 0, 4, 4, 0, 1, 2, 1, 3, 1, 4, 3, 2, 3, 4, 1, 4, 0, 1, 1,
#         2, 1, 2, 0, 3, 1, 2, 2, 2, 2, 3, 0, 4, 1, 2, 1, 2, 0, 0, 3, 0, 0, 0, 1,
#         1, 3, 1, 0, 1, 1, 3, 1, 4, 2, 2, 2, 1, 0, 3, 4, 1, 3, 0, 3, 0, 1, 4, 2,
#         0, 1, 2, 1, 2, 4, 3, 3])

# %%
Data["y"]
# Out:
# tensor([2, 3, 4, 4, 4, 4, 0, 4, 4, 2, 3, 4, 1, 0, 2, 3, 1, 4, 3, 0, 0, 1, 1, 1,
#         1, 2, 4, 3, 1, 4, 1, 4, 0, 0, 2, 3, 0, 4, 1, 1, 3, 0, 0, 0, 1, 3, 4, 1,
#         3, 3, 0, 4, 2, 4, 4, 3, 3, 2, 2, 2, 3, 4, 4, 2, 4, 4, 3, 0, 4, 0, 3, 3,
#         0, 0, 1, 2, 4, 2, 0, 4, 4, 4, 2, 0, 0, 2, 0, 4, 0, 2, 3, 3, 2, 2, 3, 2,
#         2, 4, 4, 3, 3, 1, 1, 1, 0, 0, 2, 1, 2, 0, 0, 3, 3, 2, 1, 3, 3, 2, 1, 4,
#         0, 1, 3, 2, 3, 0, 4, 4, 0, 1, 2, 1, 3, 1, 4, 3, 2, 3, 4, 1, 4, 0, 1, 1,
#         2, 1, 2, 0, 3, 4, 2, 2, 2, 2, 3, 0, 4, 1, 2, 1, 2, 0, 0, 3, 0, 0, 0, 1,
#         1, 3, 1, 0, 1, 1, 3, 1, 4, 2, 2, 2, 1, 0, 3, 4, 1, 3, 0, 3, 0, 1, 4, 2,
#         0, 1, 2, 1, 2, 4, 3, 3])

# %%
import seaborn as sn
confusion_matrix = pd.crosstab(Data['y'], pred_t, rownames=['Actual'], colnames = ['Predicted'], margins = True)
plt.figure(figsize=(8, 6))
sn.heatmap(confusion_matrix, annot=True,  cmap="Blues", fmt='g')
plt.title('Second scenario, confusion matrix (BGAT) for the whole data')
plt.show()

# %%
pred = pred_t[Data["test_mask"]]

# %%
act = Data["y"][Data["test_mask"]]

# %%
data = {'y_Actual':    act,
        'y_Predicted':pred
        }

df = pd.DataFrame(data, columns = ['y_Actual','y_Predicted'])
df
# Out:
#     y_Actual  y_Predicted
# 0          0            0
# 1          3            3
# 2          0            0
# 3          2            2
# 4          4            4
# 5          2            2
# 6          0            0
# 7          1            1
# 8          4            4
# 9          4            4
# 10         2            2
# 11         3            4
# 12         4            4
# 13         1            1
# 14         1            1
# 15         1            1
# 16         3            3
# 17         2            2
# 18         3            3
# 19         0            0

# %%
import seaborn as sn
confusion_matrix = pd.crosstab(act, pred, rownames=['Actual'], colnames = ['Predicted'], margins = True)
plt.figure(figsize=(8, 6))
sn.heatmap(confusion_matrix, annot=True,  cmap="Blues", fmt='g')
plt.title('Second scenario, confusion matrix (BGAT) for the test data')
plt.show()

# %%
from sklearn.metrics import roc_auc_score, f1_score, recall_score
# Assuming these are your predicted and true labels in PyTorch tensors
y_pred = pred_t
y_true = Data["y"]

# Convert predicted and true labels to NumPy arrays
out = model(Data["x"], Data["edge_index"])
pred = out.argmax(dim = 1)
y_pred_np = pred[Data["test_mask"]]

y_true_np = Data["y"][Data["test_mask"]]
# Calculate F-score and recall per class
f_score = f1_score(y_true_np, y_pred_np, average='macro')
recall = recall_score(y_true_np, y_pred_np, average='macro')

print(f'F-score: {f_score:.3f}')
print(f'Recall: {recall:.3f}')
# Out:
# F-score: 0.949
# Recall: 0.950

# %%
from sklearn.metrics import cohen_kappa_score

# Calculate Cohen's Kappa
kappa = cohen_kappa_score(y_true_np, y_pred_np)

print(f'Cohen\'s Kappa: {kappa:.3f}')
# Out:
# Cohen's Kappa: 0.938

# %%
from sklearn.metrics import precision_score
average_precision = precision_score(y_true_np, y_pred_np, average='macro')
print(f'Average Precision: {average_precision:.3f}')
# Out:
# Average Precision: 0.960
